# %%
import numpy as np
import matplotlib.pyplot as plt

# Load the .npy file
loaded_array = np.load('loss_data_012567.npy')

#loss_row = torch.tensor([epoch,errD.data[0],errG.data[0],errD_real.data[0],errD_fake.data[0],errD_fake_1.data[0],errD_fake_2.data[0]])
iteration = loaded_array[:,0]
errD = loaded_array[:,1]
errG = loaded_array[:,2]
errD_real = loaded_array[:,3]
errD_fake = loaded_array[:,4]


plt.plot(iteration,errD_real,"b",label="errD_fake1")
plt.xlabel("epochs")
plt.ylabel("loss")
plt.title("Discriminator Loss -- Real sample")
# Out:
# Text(0.5, 1.0, 'Discriminator Loss')
